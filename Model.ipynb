# %%
# %matplotlib notebook
from Agent_Based_Model import simulation, get_displays
PopulationNumber = 20000 #starting population number
WorldHorizontalSize = 100 
WorldVerticalSize = 100
InfectionRate = 0.15
InfectionDuration = 15
StepSize = 5
NumberOfSteps = 60
NumberOfList = 5
NumberOfVizList = get_displays(NumberOfList, NumberOfSteps)
vaccinationRate = 0
InitialInfected = 0.02
simulation(PopulationNumber, WorldHorizontalSize, 
               WorldVerticalSize, InfectionRate,
                 InfectionDuration, StepSize, NumberOfSteps, 
                   NumberOfVizList, vaccinationRate, InitialInfected)
# Out:
# <img src="data:image/png;base64,..." width="650">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="650">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="650">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="650">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="650">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="650">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="650">
